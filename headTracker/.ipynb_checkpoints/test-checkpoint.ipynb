# %%
import cv2
import time
import mediapipe as mp
from mediapipe import solutions
import numpy as np
import matplotlib.pyplot as plt
from pprint import pprint
import math
from PIL import Image

# %%
mp_drawing = mp.solutions.drawing_utils
mp_drawing_styles = mp.solutions.drawing_styles
mp_holistic = mp.solutions.holistic
mp_pose = mp.solutions.pose
mp_face_mesh = mp.solutions.face_mesh

# %%
img_path = "crop.jpeg"
face_mesh = mp_face_mesh.FaceMesh(
    static_image_mode=True,
    max_num_faces=1,
    refine_landmarks=True,
    min_detection_confidence=0.5)


img  = cv2.imread(img_path)
h, w, _  = img.shape

results = face_mesh.process(cv2.cvtColor(img, cv2.COLOR_BGR))
# Out:
# I0000 00:00:1762311033.065297 7113427 gl_context.cc:369] GL version: 2.1 (2.1 Metal - 89.4), renderer: Apple M3 Pro
# W0000 00:00:1762311033.068502 7113694 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1762311033.078486 7113693 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 12
#       9 img  = cv2.imread(img_path)
#      10 h, w, _  = img.shape
# ---> 12 results = face_mesh.process(cv2.cvtColor(img, cv2.COLOR_BGR))
#
# AttributeError: module 'cv2' has no attribute 'COLOR_BGR'
